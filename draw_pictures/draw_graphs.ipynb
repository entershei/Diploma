# %%
from graphviz import Digraph, Graph

# %%
fg = Digraph(name='Functional graph', comment='The example of functional graph')
fg.edge_attr.update(arrowsize='0.7')
fg.attr('node', shape='circle', fixedsize='true', width='0.3')
fg.engine = 'neato'

fg.node('1', pos='0,0!')
fg.node('12', pos='0.6,0!')
fg.node('8', pos='1.2,0!')
fg.node('2', pos='1.2,-0.6!')
fg.node('3', pos='1.8,-0.6!')
fg.node('10', pos='2.4,-0.6!')
fg.node('5', pos='3,-0.6!')
fg.node('13', pos='3.6,-0.6!')
fg.node('4', pos='0,-0.6!')
fg.node('9', pos='1.2,-1.2!')
fg.node('6', pos='0.6,-1.2!')
fg.node('11', pos='2.4,0!')
fg.node('7', pos='2.4,-1.2!')


fg.edges(['41', '69', ['7', '10'], '92', ['11', '10']])
fg.edge('2', '12', color='crimson')
fg.edge('3', '3', color='crimson', headport='ne', tailport='nw')
fg.edge('5', '10', color='crimson')
fg.edge('8', '2', color='crimson')
fg.edge('10', '5', color='crimson')
fg.edge('12', '8', color='crimson')


# print(fg.source)
fg.render('pictures/functional_graph', view=False)  
fg

# %%
pt = Digraph(name='Part of tree', comment='Tree contains only the path')
pt.edge_attr.update(arrowsize='0.7')
pt.attr('node', shape='circle', fixedsize='true', width='0.3')
pt.engine = 'neato'

pt.node('1', pos='0,0!')
pt.node('12', pos='0.6,0!')
pt.node('8', pos='1.2,0!')
pt.node('2', pos='1.2,-0.6!')
pt.node('3', pos='1.8,-0.6!')
pt.node('10', pos='2.4,-0.6!')
pt.node('5', pos='3,-0.6!')
pt.node('13', pos='3.6,-0.6!')
pt.node('4', pos='0,-0.6!')
pt.node('9', pos='1.2,-1.2!')
pt.node('6', pos='0.6,-1.2!')
pt.node('11', pos='2.4,0!')
pt.node('7', pos='2.4,-1.2!')

pt.edge('1', '12')
pt.edge('12', '8')
pt.edge('8', '2')
pt.edge('2', '3')
pt.edge('3', '10')
pt.edge('10', '5')
pt.edge('5', '13')

# print(fg.source)
pt.render('pictures/part_tree1', view=False)  
pt

# %%
t = Digraph(name='Final tree', comment='Tree contains only the path')
t.edge_attr.update(arrowsize='0.7')
t.attr('node', shape='circle', fixedsize='true', width='0.3')
t.engine = 'neato'

t.node('1', pos='0,0!')
t.node('12', pos='0.6,0!')
t.node('8', pos='1.2,0!')
t.node('2', pos='1.2,-0.6!')
t.node('3', pos='1.8,-0.6!')
t.node('10', pos='2.4,-0.6!')
t.node('5', pos='3,-0.6!')
t.node('13', pos='3.6,-0.6!')
t.node('4', pos='0,-0.6!')
t.node('9', pos='1.2,-1.2!')
t.node('6', pos='0.6,-1.2!')
t.node('11', pos='2.4,0!')
t.node('7', pos='2.4,-1.2!')

t.edge('1', '12')
t.edge('12', '8')
t.edge('8', '2')
t.edge('2', '3')
t.edge('3', '10')
t.edge('10', '5')
t.edge('5', '13')

t.edge('4', '1', color='crimson')
t.edge('6', '9', color='crimson')
t.edge('7', '10', color='crimson')
t.edge('9', '2', color='crimson')
t.edge('11', '10', color='crimson')


# print(fg.source)
t.render('pictures/oriented_final_tree', view=False)  
t

# %%
t = Graph(name='Final tree', comment='Tree contains only the path')
t.edge_attr.update(arrowsize='0.7')
t.attr('node', shape='circle', fixedsize='true', width='0.3')
t.engine = 'neato'

t.node('1', pos='0,0!')
t.node('12', pos='0.6,0!')
t.node('8', pos='1.2,0!')
t.node('2', pos='1.2,-0.6!')
t.node('3', pos='1.8,-0.6!')
t.node('10', pos='2.4,-0.6!')
t.node('5', pos='3,-0.6!')
t.node('13', pos='3.6,-0.6!')
t.node('4', pos='0,-0.6!')
t.node('9', pos='1.2,-1.2!')
t.node('6', pos='0.6,-1.2!')
t.node('11', pos='2.4,0!')
t.node('7', pos='2.4,-1.2!')

t.edge('1', '12')
t.edge('12', '8')
t.edge('8', '2')
t.edge('2', '3')
t.edge('3', '10')
t.edge('10', '5')
t.edge('5', '13')

t.edge('4', '1')
t.edge('6', '9')
t.edge('7', '10')
t.edge('9', '2')
t.edge('11', '10')


# print(fg.source)
t.render('pictures/final_tree', view=False)  
t

# %%
t = Graph(name='Bipartite tree', comment='Tree contains only the path')
t.attr('node', shape='circle', fixedsize='true', width='0.4')
t.engine = 'fdp'
t.graph_attr.update({'splines': 'compound'})
# fdp neato

a = Graph(name='cluster_A', node_attr={'style': 'filled', 'color': 'white'})
a.graph_attr.update({'label': 'A-вершины', 'style': 'filled', 'color':'lightgrey'})

a.node('1', pos='0,3!')
a.node('2', pos='0,2.4!')
a.node('3', pos='0,1.8!')
a.node('4', pos='0,1.2!')
a.node('5', pos='0,0.6!')
a.node('6', pos='0,0!')

a.edge('2', '4', color='red2', headport='nw', tailport='sw', splines='line')
a.edge('5', '6', color='red2')

t.subgraph(a)

b = Graph(name='cluster_B', node_attr={'style': 'filled'})
b.graph_attr.update({'label': 'B-вершины'})

b.node('7', pos='2,3.6!')
b.node('8', pos='2,3!')
b.node('9', pos='2,2.4!')
b.node('10', pos='2,1.8!')
b.node('11', pos='2,1.2!')
b.node('12', pos='2,0.6!')
b.node('13', pos='2,0!')
b.node('14', pos='2,-0.6!')

b.edge('9', '10', color='mediumblue')
b.edge('10', '12', color='mediumblue', headport='ne', tailport='se')
b.edge('12', '13', color='mediumblue')
b.edge('12', '14', color='mediumblue', headport='ne', tailport='se')

t.subgraph(b)

t.edge('1', '7')
t.edge('1', '8')
t.edge('2', '8')
t.edge('3', '9')
t.edge('4', '11')
t.edge('5', '13')
t.edge('6', '11')

# print(fg.source)
t.render('pictures/bipartite_tree', view=False)  
t

# %%
t = Digraph(name='Bipartite functional graph')
t.edge_attr.update(arrowsize='0.6')
t.attr('node', shape='circle', fixedsize='true', width='0.4')
t.engine = 'fdp'
t.graph_attr.update({'splines': 'compound'})
# fdp neato

a = Digraph(name='cluster_A', node_attr={'style': 'filled', 'color': 'white'})
a.graph_attr.update({'label': 'A-вершины', 'style': 'filled', 'color':'lightgrey'})

a.node('1', pos='0,3!')
a.node('2', pos='0,2.4!')
a.node('3', pos='0,1.8!')
a.node('4', pos='0,1.2!')
a.node('5', pos='0,0.6!')
a.node('6', pos='0,0!')

# a.edge('2', '4', color='red2', headport='nw', tailport='sw', splines='line')
# a.edge('5', '6', color='red2')

t.subgraph(a)

b = Digraph(name='cluster_B', node_attr={'style': 'filled'})
b.graph_attr.update({'label': 'B-вершины'})

b.node('7', pos='2,3.6!')
b.node('8', pos='2,3!')
b.node('9', pos='2,2.4!')
b.node('10', pos='2,1.8!')
b.node('11', pos='2,1.2!')
b.node('12', pos='2,0.6!')
b.node('13', pos='2,0!')
b.node('14', pos='2,-0.6!')

# b.edge('9', '10', color='mediumblue')
# b.edge('10', '12', color='mediumblue', headport='ne', tailport='se')
# b.edge('12', '13', color='mediumblue')
# b.edge('12', '14', color='mediumblue', headport='ne', tailport='se')

t.subgraph(b)

t.edge('2', '8', headport='nw', tailport='ne', color="red3", style='dashed')
t.edge('3', '9')
t.edge('4', '4', color="red3", style='dashed')
t.edge('5', '11', color="red3", style='dashed')
t.edge('6', '5', color="red3")
t.edge('7', '1')
t.edge('8', '2', headport='se', tailport='sw', color="red3")
t.edge('9', '10')
t.edge('10', '12')
t.edge('11', '6', color="red3")
t.edge('12', '13', headport='nw', tailport='sw', color="red3", style='dashed')
t.edge('13', '12', headport='se', tailport='ne', color="red3")

# print(fg.source)
t.render('pictures/bipartite_functional_graph', view=False)  
t

# %%
t = Digraph(name='Bipartite functional tree, replaced edges')
t.edge_attr.update(arrowsize='0.6')
t.attr('node', shape='circle', fixedsize='true', width='0.4')
t.engine = 'fdp'
t.graph_attr.update({'splines': 'compound'})
# fdp neato

a = Digraph(name='cluster_A', node_attr={'style': 'filled', 'color': 'white'})
a.graph_attr.update({'label': 'A-вершины', 'style': 'filled', 'color':'lightgrey'})

a.node('1', pos='0,3!')
a.node('2', pos='0,2.4!')
a.node('3', pos='0,1.8!')
a.node('4', pos='0,1.2!')
a.node('5', pos='0,0.6!')
a.node('6', pos='0,0!')

t.subgraph(a)

b = Digraph(name='cluster_B', node_attr={'style': 'filled'})
b.graph_attr.update({'label': 'B-вершины'})

b.node('7', pos='2,3.6!')
b.node('8', pos='2,3!')
b.node('9', pos='2,2.4!')
b.node('10', pos='2,1.8!')
b.node('11', pos='2,1.2!')
b.node('12', pos='2,0.6!')
b.node('13', pos='2,0!')
b.node('14', pos='2,-0.6!')

t.subgraph(b)

t.edge('1', '8', color="red3")
t.edge('2', '4', headport='nw', tailport='sw', color="red3")
t.edge('3', '9')
t.edge('4', '11', color="red3")
t.edge('5', '13', color="red3")
t.edge('6', '5')
t.edge('7', '1')
t.edge('8', '2')
t.edge('9', '10')
t.edge('10', '12')
t.edge('11', '6')
t.edge('12', '14', color="red3")
t.edge('13', '12')

# print(fg.source)
t.render('pictures/bipartite_tree_replaces_edges', view=False)  
t

# %%
t = Digraph(name='Circles')
t.edge_attr.update(arrowsize='0.6')
t.attr('node', shape='circle', fixedsize='true', width='0.4')
t.engine = 'dot'
t.graph_attr.update({'splines': 'compound'})
# fdp neato

c1 = Digraph(name='cluster_1')
c1.node('2')
c1.node('8', style='filled', color='lightgrey')

c2 = Digraph(name='cluster_2')
c2.node('4')

c3 = Digraph(name='cluster_3')
c3.node('5')
c3.node('6')
c3.node('11', style='filled', color='lightgrey')

c4 = Digraph(name='cluster_4')
c4.node('12', style='filled', color='lightgrey')
c4.node('13', style='filled', color='lightgrey')

t.subgraph(c1)
t.subgraph(c2)
t.subgraph(c3)
t.subgraph(c4)

# print(fg.source)
t.render('pictures/circles', view=False)  
t

# %%
t = Digraph(name='Circles')
t.edge_attr.update(arrowsize='0.6')
t.attr('node', shape='circle', fixedsize='true', width='0.4')
t.engine = 'dot'
t.graph_attr.update({'splines': 'compound'})
# fdp neato

c0 = Digraph(name='cluster_0')
c0.node('1')

c1 = Digraph(name='cluster_1')
c1.node('2')
c1.node('8', style='filled', color='lightgrey')

c2 = Digraph(name='cluster_2')
c2.node('4')

c3 = Digraph(name='cluster_3')
c3.node('5')
c3.node('6')
c3.node('11', style='filled', color='lightgrey')

c4 = Digraph(name='cluster_4')
c4.node('12', style='filled', color='lightgrey')
c4.node('13', style='filled', color='lightgrey')

c5 = Digraph(name='cluster_5')
c5.node('14')

t.subgraph(c0)
t.subgraph(c1)
t.subgraph(c2)
t.subgraph(c3)
t.subgraph(c4)
t.subgraph(c5)

t.edge('1', '8', constraint='false')
t.edge('2', '4', constraint='false', color='red3')
t.edge('4', '11', constraint='false')
t.edge('5', '13', constraint='false')
t.edge('12', '14', constraint='false', color='mediumblue')

# print(fg.source)
t.render('pictures/pi', view=False)  
t

# %%
t = Graph(name='new_FBM', comment='')
# t.edge_attr.update(arrowsize='0.7')
t.attr('node', shape='circle', fixedsize='true', width='0.3', ordering="out")
t.engine = 'circo'

t.edge('0l', '0r', color='black')
t.edge('0l', '0r', color='chartreuse2')

t.edge('0r', '1l', style='invis')

t.edge('1l', '1r', color='black')
t.edge('1l', '1r', color='blue')

t.edge('1r', '2l', style='invis')

t.edge('2l', '2r', color='black')
t.edge('2l', '2r', color='chartreuse2')

t.edge('2r', '3l', style='invis')

t.edge('3l', '3r', color='black')
t.edge('3l', '3r', color='blue')

t.edge('3r', '4l', style='invis')

t.edge('4l', '4r', color='black')
t.edge('4l', '4r', color='chartreuse2')

t.edge('4r', '5l', style='invis')

t.edge('5l', '5r', color='black')
t.edge('5l', '5r', color='chartreuse2')

t.edge('5r', '0l', style='invis')


# print(fg.source)
t.render('pictures/new_FBM', view=False)  
t

# %%
t = Digraph(name='DCJ_AA', comment='')
# t.edge_attr.update(arrowsize='0.7')
t.attr('node', shape='circle', fixedsize='true', width='0.3', ordering="out")
t.engine = 'circo'

t.edge('0l', '0r', color='black', dir='none')
t.edge('0l', '0r', color='chartreuse2', dir='none')

t.edge('0r', '1l', style='invis')

t.edge('1l', '1r', color='black', dir='none')
t.edge('1l', '1r', color='blue', dir='none')

t.edge('1r', '2l', style='invis')

t.edge('2l', '2r', color='black', dir='none')
t.edge('2l', '2r', color='chartreuse2', style='dashed', dir='none')

t.edge('2r', '3l', style='invis', dir='none')

t.edge('3l', '3r', color='black', dir='none')
t.edge('3l', '3r', color='blue', dir='none')

t.edge('3r', '4l', style='invis', dir='none')

t.edge('4l', '4r', color='black', dir='none')
t.edge('4l', '4r', color='chartreuse2', style='dashed', dir='none')

t.edge('4r', '0l', style='invis')

t.node('0la', label='0l')
t.node('0ra', label='0r')
t.node('1la', label='1l')
t.node('1ra', label='1r')
t.node('2la', label='2l')
t.node('2ra', label='2r')
t.node('3la', label='3l')
t.node('3ra', label='3r')
t.node('4la', label='4l')
t.node('4ra', label='4r')
t.node('l', style='invis')
t.node('r', style='invis')

t.edge('0la', '0ra', color='black', dir='none')
t.edge('0la', '0ra', color='chartreuse2', dir='none')

t.edge('0ra', '1la', style='invis')

t.edge('1la', '1ra', color='black', dir='none')
t.edge('1la', '1ra', color='blue', dir='none')

t.edge('1ra', '2la', style='invis')

t.edge('2la', '2ra', color='black', dir='none')
# t.edge('2la', '2ra', color='chartreuse2', style='dashed', dir='none')

t.edge('2ra', '3la', style='invis')

t.edge('3la', '3ra', color='black', dir='none')
t.edge('3la', '3ra', color='blue', dir='none')

t.edge('3ra', '4la', style='invis')

t.edge('4la', '4ra', color='black', dir='none')
# t.edge('4la', '4ra', color='chartreuse2', style='dashed', dir='none')

t.edge('4ra', '0la', style='invis')

t.edge('4r', 'l', style='invis')
t.edge('l', 'r', style='bold', label='A, A ДРС')
t.edge('r', '2la', style='invis')

# print(fg.source)
t.render('pictures/DCJ_AA', view=False)  
t

# %%
t = Digraph(name='DCJ_AB', comment='')
# t.edge_attr.update(arrowsize='0.7')
t.attr('node', shape='circle', fixedsize='true', width='0.3', ordering="out")
t.engine = 'circo'

t.edge('0l', '0r', color='black', dir='none')
t.edge('0l', '0r', color='chartreuse2', dir='none')

t.edge('0r', '1l', style='invis')

t.edge('1l', '1r', color='black', dir='none')
t.edge('1l', '1r', color='blue', dir='none', style='dashed')

t.edge('1r', '2l', style='invis')

t.edge('2l', '2r', color='black', dir='none')
t.edge('2l', '2r', color='chartreuse2', dir='none')

t.edge('2r', '3l', style='invis', dir='none')

t.edge('3l', '3r', color='black', dir='none')
t.edge('3l', '3r', color='blue', dir='none')

t.edge('3r', '4l', style='invis', dir='none')

t.edge('4l', '4r', color='black', dir='none')
t.edge('4l', '4r', color='chartreuse2', style='dashed', dir='none')

t.edge('4r', '0l', style='invis')

t.node('0la', label='0l')
t.node('0ra', label='0r')
t.node('1la', label='1l')
t.node('1ra', label='1r')
t.node('2la', label='2l')
t.node('2ra', label='2r')
t.node('3la', label='3l')
t.node('3ra', label='3r')
t.node('4la', label='4l')
t.node('4ra', label='4r')
t.node('l', style='invis')
t.node('r', style='invis')

t.edge('0la', '0ra', color='black', dir='none')
t.edge('0la', '0ra', color='chartreuse2', dir='none')

t.edge('0ra', '1la', style='invis')

t.edge('1la', '1ra', color='black', dir='none')
t.edge('1la', '1ra', color='blue', dir='none', style='invis')

t.edge('1ra', '2la', style='invis')

t.edge('2la', '2ra', color='black', dir='none')
t.edge('2la', '2ra', color='chartreuse2', dir='none')

t.edge('2ra', '3la', style='invis')

t.edge('3la', '3ra', color='black', dir='none')
t.edge('3la', '3ra', color='blue', dir='none')

t.edge('3ra', '4la', style='invis')

t.edge('4la', '4ra', color='black', dir='none')
t.edge('4la', '4ra', color='chartreuse2', dir='none', style='invis')

t.edge('4ra', '0la', style='invis')

t.edge('4r', 'l', style='invis')
t.edge('l', 'r', style='bold', label='A, A ДРС')
t.edge('r', '2la', style='invis')

# print(fg.source)
t.render('pictures/DCJ_AB', view=False)  
t

# %%
t = Digraph(name='DCJ_BB', comment='')
# t.edge_attr.update(arrowsize='0.7')
t.attr('node', shape='circle', fixedsize='true', width='0.3', ordering="out")
t.engine = 'circo'

t.edge('0l', '0r', color='black', dir='none')
t.edge('0l', '0r', color='chartreuse2', dir='none')

t.edge('0r', '1l', style='invis')

t.edge('1l', '1r', color='black', dir='none')
t.edge('1l', '1r', color='blue', dir='none', style='dashed')

t.edge('1r', '2l', style='invis')

t.edge('2l', '2r', color='black', dir='none')
t.edge('2l', '2r', color='chartreuse2', dir='none')

t.edge('2r', '3l', style='invis', dir='none')

t.edge('3l', '3r', color='black', dir='none')
t.edge('3l', '3r', color='blue', dir='none', style='dashed')

t.edge('3r', '4l', style='invis', dir='none')

t.edge('4l', '4r', color='black', dir='none')
t.edge('4l', '4r', color='chartreuse2', dir='none')

t.edge('4r', '0l', style='invis')

t.node('0la', label='0l')
t.node('0ra', label='0r')
t.node('1la', label='1l')
t.node('1ra', label='1r')
t.node('2la', label='2l')
t.node('2ra', label='2r')
t.node('3la', label='3l')
t.node('3ra', label='3r')
t.node('4la', label='4l')
t.node('4ra', label='4r')
t.node('l', style='invis')
t.node('r', style='invis')

t.edge('0la', '0ra', color='black', dir='none')
t.edge('0la', '0ra', color='chartreuse2', dir='none')

t.edge('0ra', '1la', style='invis')

t.edge('1la', '1ra', color='black', dir='none')
t.edge('1la', '1ra', color='blue', dir='none', style='invis')

t.edge('1ra', '2la', style='invis')

t.edge('2la', '2ra', color='black', dir='none')
t.edge('2la', '2ra', color='chartreuse2', dir='none')

t.edge('2ra', '3la', style='invis')

t.edge('3la', '3ra', color='black', dir='none')
t.edge('3la', '3ra', color='blue', dir='none', style='invis')

t.edge('3ra', '4la', style='invis')

t.edge('4la', '4ra', color='black', dir='none')
t.edge('4la', '4ra', color='chartreuse2', dir='none')

t.edge('4ra', '0la', style='invis')

t.edge('4r', 'l', style='invis')
t.edge('l', 'r', style='bold', label='A, A ДРС')
t.edge('r', '2la', style='invis')

# print(fg.source)
t.render('pictures/DCJ_BB', view=False)  
t

# %%
t = Graph(name='DCJ_to_spanning_tree', comment='')
t.attr('node', shape='circle', fixedsize='true', width='0.3', ordering="out")
t.engine = 'circo'

t.edge('0l', '0r', color='black')
# t.edge('0l', '0r', color='chartreuse2', style='dashed')

t.edge('0r', '1l', style='invis')

t.edge('1l', '1r', color='black')
# t.edge('1l', '1r', color='blue', style='dashed')

t.edge('1r', '2l', style='invis')

t.edge('2l', '2r', color='black')
# t.edge('2l', '2r', color='blue', style='dashed')

t.edge('2r', '0l', style='invis')


# print(fg.source)
t.render('pictures/DCJ_to_spanning_tree3', view=False)  
t

# %%
t = Graph(name='DCJ_to_spanning_tree', comment='')
t.attr('node', shape='circle', fixedsize='true', width='0.3', ordering="out")
t.engine = 'circo'

t.node('0', color='blue')
t.node('1', color='blue')
t.node('2', color='chartreuse2')

t.edge('0', '1', style='invis')
t.edge('1', '2')
t.edge('2', '0')

# t.edge('2l', '2r', color='blue', style='dashed')


# print(fg.source)
t.render('pictures/DCJ_to_spanning_tree6', view=False)  
t
